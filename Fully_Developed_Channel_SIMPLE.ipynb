# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
from numba import jit

# %% [markdown]
# # Parameters

# %%
nx = 51 # number of continuity/scalar/pressure control volumes in x-direction
ny = 51 # number of continuity/scalar/pressure control volumes in y-direction
x_min, x_max = 0., 10.
y_min, y_max = 0., 1.
dx = (x_max-x_min)/nx
dy = (y_max-y_min)/ny
# Set fluid properties
μ = 0.01
ρ = 1.0

# number of outer iterations
outer_iterations = 1000

# set relaxation factors
ω_u = 0.7 # x-momentum under-relaxation
ω_v = 0.7 # y-momentum under-relaxation
ω_p = 0.3 # pressure update under-relaxation

# SOR over-relaxation factor
Ω = 1.7

# %% [markdown]
# # Initialize Arrays
#
# Initialize variables for channel flow, <br>
# + $u=0, v=0, p=0$ <br>
#
# Set the boundary conditions,
# + inlet / inflow at the left boundary
# + upper wall
# + bottom wall

# %%
u = np.zeros([ny+2,nx+2])
v = np.zeros([ny+2,nx+2])
p = np.zeros([ny+2,nx+2])
u_old = np.zeros([ny+2,nx+2])
v_old = np.zeros([ny+2,nx+2])
p_corr = np.zeros([ny+2,nx+2])

Apu = np.ones([ny+2,nx+2])
Apv = np.ones([ny+2,nx+2])
App = np.ones([ny+2,nx+2])
Ae = np.ones([ny+2,nx+2])
Aw = np.ones([ny+2,nx+2])
An = np.ones([ny+2,nx+2])
As = np.ones([ny+2,nx+2])

source = np.zeros([ny+2,nx+2])

u_nodal = np.zeros([ny+2,nx+2])
v_nodal = np.zeros([ny+2,nx+2])
p_nodal = np.zeros([ny+2,nx+2])
x_nodal = np.zeros([ny+2,nx+2])
y_nodal = np.zeros([ny+2,nx+2])
Vel_mag = np.zeros([ny+2,nx+2])

# %% [markdown]
# **Set inlet and wall boundary conditions for channel flow**

# %%
u[0,:] = 0.0 # zero on bottom wall, (for tangential component index starts with 0)
u[ny+1,:] = 0.0 # zero on upper wall 
u[:,1] = 1.0 # u=1 at inlet/left boundary (for normal component index starts with 1)
u[:,nx+1] = u[:,1] # set outlet to inlet; conserve mass overall

# %% [markdown]
# Initialize **u_old** and **v_old**

# %%
u_old[:,:] = u[:,:]
v_old[:,:] = v[:,:]

# %% [markdown]
# **Begin outer iterations for sequential loop procedure**

# %%
for outeriterations in range(1,outer_iterations+1):
    # X-momentum equation solution
    # set  x-momentum equation coefficients
    for j in range(1,ny+1):
        for i in range(2,nx+1):
            Ae[j,i] = max(-0.5*ρ*dy*(u_old[j,i+1]+u_old[j,i]),0.)+μ*dy/dx
            Aw[j,i] = max( 0.5*ρ*dy*(u_old[j,i-1]+u_old[j,i]),0.)+μ*dy/dx
            An[j,i] = max(-0.5*ρ*dx*(v_old[j+1,i]+v_old[j+1,i-1]),0.)+μ*dx/dy
            As[j,i] = max( 0.5*ρ*dx*(v_old[j,i]+v_old[j,i-1]),0.)+μ*dx/dy
            
    # overwrite boundary coefficients along north/south walls with half cell (dy) size
    for i in range(2,nx+1):
        An[ny,i] = max(-0.5*ρ*dx*(v_old[ny+1,i]+v_old[ny+1,i-1]),0.)+μ*dx/(dy/2)
        As[1,i] = max( 0.5*ρ*dx*(v_old[1,i]+v_old[1,i-1]),0.)+μ*dx/(dy/2)
        
    Apu[:,:] = Ae[:,:]+Aw[:,:]+An[:,:]+As[:,:]
    
    # Block out cells
    #Apu[1:12,20:21] = 1.e30
    
    # Under-relaxation
    Apu[:,:] = Apu[:,:]/ω_u
    
    # Iterate x-momentum equations
    for _ in range(1,10+1):
        for j in range(1,ny+1):
            for i in range(2,nx+1):
                u[j,i] = (1.-ω_u)*u_old[j,i] + 1./Apu[j,i]*(Ae[j,i]*u[j,i+1]+Aw[j,i]*u[j,i-1]+An[j,i]*u[j+1,i] \
                                                           + As[j,i]*u[j-1,i]+dy*(p[j,i-1]-p[j,i]))
    
    # Apply outflow boundary condition (du/dx = 0)
    u[:,nx+1] = u[:,nx]
    
    # Ensure overall mass conservation
    mass_inflow = 1.0  # analytical value based on ρ*u*L (L=channel height at inlet)
    mass_outflow = 0.0
    for j in range(1,ny+1):
        mass_outflow = mass_outflow + ρ*dy*u[j,nx+1]
    u[:,nx+1] = u[:,nx+1]*mass_inflow/mass_outflow # outflow mass correction for channel
    
    # Condition to generate fully developed flow in channel (else comment out)
    u[:,1] = u[:,nx+1]
    
    # Solve y-momentum equation
    for j in range(2,ny+1):
        for i in range(1,nx+1):
            Ae[j,i] = max(-0.5*ρ*dy*(u_old[j,i+1]+u_old[j-1,i+1]),0.)+μ*dy/dx
            Aw[j,i] = max( 0.5*ρ*dy*(u_old[j,i]+u_old[j-1,i]),0.)+μ*dy/dx
            An[j,i] = max(-0.5*ρ*dx*(v_old[j,i]+v_old[j+1,i]),0.)+μ*dx/dy
            As[j,i] = max( 0.5*ρ*dx*(v_old[j,i]+v_old[j-1,i]),0.)+μ*dx/dy
            
    # overwrite boundary coefficients along east/west cells due to half cell (dx) size
    for j in range(2,ny+1):
        Ae[j,nx] = max(-0.5*ρ*dy*(u_old[j,nx+1]+u_old[j-1,nx+1]),0.)+μ*dy/(dx/2.)
        Aw[j,1] = max( 0.5*ρ*dy*(u_old[j,1]+u_old[j-1,1]),0.)+μ*dy/(dx/2.)
            
    Apv[:,:] = Ae[:,:]+Aw[:,:]+An[:,:]+As[:,:]
    
    # Block out cells
    #Apv[1:13,21:21]=1.e30
    
    # Under-relaxation
    Apv[:,:] = Apv[:,:]/ω_v
    
    # Iterate y-momentum equations
    for _ in range(10+1):
        for j in range(2,ny+1):
            for i in range(1,nx+1):
                v[j,i] = (1.-ω_v)*v_old[j,i] + 1./Apv[j,i]*(Ae[j,i]*v[j,i+1]+Aw[j,i]*v[j,i-1]+An[j,i]*v[j+1,i] \
                                                           + As[j,i]*v[j-1,i]+dx*(p[j-1,i]-p[j,i]))
    # Pressure correction equation
    # set coefficients
    for j in range(1,ny+1):
        for i in range(1,nx+1):
            Ae[j,i] = ρ*dy**2./Apu[j,i+1]
            Aw[j,i] = ρ*dy**2./Apu[j,i]
            An[j,i] = ρ*dx**2./Apv[j+1,i]
            As[j,i] = ρ*dx**2./Apv[j,i]
            
    # set boundary values for correction
    Ae[:,nx] = 0.0
    Aw[:,1]  = 0.0
    An[ny,:] = 0.0
    As[1,:]  = 0.0
    
    App[:,:]=Ae[:,:]+Aw[:,:]+An[:,:]+As[:,:]
    App[1,1]=1.e30 # set reference cell value for pressure
    p_corr[:,:] = 0.0 # initialize corrections to zero
    
    source[:,:] = 0.0
    # compute the mass-source term
    for j in range(1,ny+1):
        for i in range(1,nx+1):
            source[j,i] = ρ*dy*(u[j,i+1]-u[j,i]) + ρ*dx*(v[j+1,i]-v[j,i])
            
    # compute square root of sum of squares of mass imbalance
    mass_residue = np.sum(np.square(source[:,:]))
    mass_residue = np.sqrt(mass_residue)
    print(f'outer iteration = {outeriterations}, mass residue = {mass_residue}')
    
    # SOR iterations to solve for pressure correction, p_corr
    for _ in range(1,101):
        for j in range(1,ny+1):
            for i in range(1,nx+1):
                p_corr[j,i] = p_corr[j,i] + Ω/App[j,i]*(Ae[j,i]*p_corr[j,i+1]+Aw[j,i]*p_corr[j,i-1]+An[j,i]*p_corr[j+1,i] \
                                                       + As[j,i]*p_corr[j-1,i]-source[j,i]-App[j,i]*p_corr[j,i])
                
    # Apply corrections to pressure
    for j in range(1,ny+1):
        for i in range(1,nx+1):
            p[j,i] = p[j,i] + ω_p*p_corr[j,i]
    
    # Apply corrections to u-velocity
    for j in range(1,ny+1):
        for i in range(2,nx+1):
            u[j,i] = u[j,i] + (dy/Apu[j,i])*(p_corr[j,i-1]-p_corr[j,i])
    
    # Apply corrections to v-velocity
    for j in range(2,ny+1):
        for i in range(1,nx+1):
            v[j,i] = v[j,i] + (dx/Apv[j,i])*(p_corr[j-1,i]-p_corr[j,i])
            
    # Update velocity variables
    u_old[:,:] = u[:,:]
    v_old[:,:] = v[:,:]
    
    # note - u_old and v_old are now mass conserving
    # recompute source term to verify that mass is being conserved after corrections
    source[:,:] = 0.0
    # compute the mass-source term
    for j in range(1,ny+1):
        for i in range(1,nx+1):
            source[j,i] = ρ*dy*(u[j,i+1]-u[j,i]) + ρ*dx*(v[j+1,i]-v[j,i])
            
    # compute square root of sum of squares of mass imbalance
    mass_residue = np.sum(np.square(source[:,:]))
    mass_residue = np.sqrt(mass_residue)
    print(f'outer iteration = {outeriterations}, mass residue = {mass_residue}')
    print()
    
    # End of outer iteration loop
# Out:
# outer iteration = 1, mass residue = 0.18934145368774052
# outer iteration = 1, mass residue = 0.31452213514916183
#
# outer iteration = 2, mass residue = 0.3386462991766664
# outer iteration = 2, mass residue = 0.3793227035232855
#
# outer iteration = 3, mass residue = 0.3781940584299687
# outer iteration = 3, mass residue = 0.42007137432713965
#
# outer iteration = 4, mass residue = 0.41614448876559235
# outer iteration = 4, mass residue = 0.43563369077893943
#
# outer iteration = 5, mass residue = 0.4312850470451249
# outer iteration = 5, mass residue = 0.4400237796270607
#
# outer iteration = 6, mass residue = 0.43483225054058755
# outer iteration = 6, mass residue = 0.44084969541205604
#
# outer iteration = 7, mass residue = 0.43538457931154256
# outer iteration = 7, mass residue = 0.44076714974286074
#
# outer iteration = 8, mass residue = 0.43559127626858224
# outer iteration = 8, mass residue = 0.44038566964706893
#
# outer iteration = 9, mass residue = 0.4358226462440995
# outer iteration = 9, mass residue = 0.43987973318892365
#
# outer iteration = 10, mass residue = 0.43610329228168565
# outer iteration = 10, mass residue = 0.4393601867121991
#
# outer iteration = 11, mass residue = 0.4363929156956341
# outer iteration = 11, mass residue = 0.438770127027768
#
# outer iteration = 12, mass residue = 0.43647095518137935
# outer iteration = 12, mass residue = 0.4377609303421048
#
# outer iteration = 13, mass residue = 0.4358689608680445
# outer iteration = 13, mass residue = 0.4356207389008742
#
# outer iteration = 14, mass residue = 0.4338026036060508
# outer iteration = 14, mass residue = 0.4312638712656436
#
# outer iteration = 15, mass residue = 0.42913496628192593
# outer iteration = 15, mass residue = 0.42331024235911935
#
# outer iteration = 16, mass residue = 0.42045353129778723
# outer iteration = 16, mass residue = 0.4102615960226701
#
# outer iteration = 17, mass residue = 0.40626863141954467
# outer iteration = 17, mass residue = 0.39073704998222214
#
# outer iteration = 18, mass residue = 0.385259939219576
# outer iteration = 18, mass residue = 0.36370072241825024
#
# outer iteration = 19, mass residue = 0.35651447411496895
# outer iteration = 19, mass residue = 0.3285981258435901
#
# outer iteration = 20, mass residue = 0.31965561075908816
# outer iteration = 20, mass residue = 0.28536136149936153
#
# outer iteration = 21, mass residue = 0.27488167750114223
# outer iteration = 21, mass residue = 0.2343449160471244
#
# outer iteration = 22, mass residue = 0.22294827030523168
# outer iteration = 22, mass residue = 0.17620160849953526
#
# outer iteration = 23, mass residue = 0.16536399087033893
# outer iteration = 23, mass residue = 0.11193593551190958
#
# outer iteration = 24, mass residue = 0.10598649811310412
# outer iteration = 24, mass residue = 0.044338683213597976
#
# outer iteration = 25, mass residue = 0.061637279015347796
# outer iteration = 25, mass residue = 0.040655421460174354
#
# outer iteration = 26, mass residue = 0.06541974936075584
# outer iteration = 26, mass residue = 0.10575621394264677
#
# outer iteration = 27, mass residue = 0.09924580562510041
# outer iteration = 27, mass residue = 0.16049983456206215
#
# outer iteration = 28, mass residue = 0.1403392327003566
# outer iteration = 28, mass residue = 0.20607793742948502
#
# outer iteration = 29, mass residue = 0.17824979850741002
# outer iteration = 29, mass residue = 0.24416884535202518
#
# outer iteration = 30, mass residue = 0.21212414934869958
# outer iteration = 30, mass residue = 0.2758904742951062
#
# outer iteration = 31, mass residue = 0.2420501301737914
# outer iteration = 31, mass residue = 0.3019840888509566
#
# outer iteration = 32, mass residue = 0.2681584412633217
# outer iteration = 32, mass residue = 0.32296468695917085
#
# outer iteration = 33, mass residue = 0.29054632025528065
# outer iteration = 33, mass residue = 0.33919965931156676
#
# outer iteration = 34, mass residue = 0.30928064543901473
# outer iteration = 34, mass residue = 0.35095033992329755
#
# outer iteration = 35, mass residue = 0.3244039151963077
# outer iteration = 35, mass residue = 0.35840071703607346
#
# outer iteration = 36, mass residue = 0.3359406392700143
# outer iteration = 36, mass residue = 0.3616904329264238
#
# outer iteration = 37, mass residue = 0.3439061203806384
# outer iteration = 37, mass residue = 0.36094329281463683
#
# outer iteration = 38, mass residue = 0.3483166931215162
# outer iteration = 38, mass residue = 0.35629486002306154
#
# outer iteration = 39, mass residue = 0.34920239589610713
# outer iteration = 39, mass residue = 0.3479192474933581
#
# outer iteration = 40, mass residue = 0.34662137968719414
# outer iteration = 40, mass residue = 0.33605105343101244
#
# outer iteration = 41, mass residue = 0.340673913017564
# outer iteration = 41, mass residue = 0.32099745356587894
#
# outer iteration = 42, mass residue = 0.3315132179809641
# outer iteration = 42, mass residue = 0.30314262351452065
#
# outer iteration = 43, mass residue = 0.3193535799733448
# outer iteration = 43, mass residue = 0.2829444241910722
#
# outer iteration = 44, mass residue = 0.304475059805333
# outer iteration = 44, mass residue = 0.2609242994326526
#
# outer iteration = 45, mass residue = 0.2872245233602063
# outer iteration = 45, mass residue = 0.23765337989769963
#
# outer iteration = 46, mass residue = 0.2680131153542855
# outer iteration = 46, mass residue = 0.21373532458670463
#
# outer iteration = 47, mass residue = 0.24731211505018763
# outer iteration = 47, mass residue = 0.18978885212625257
#
# outer iteration = 48, mass residue = 0.2256431598734077
# outer iteration = 48, mass residue = 0.1664243639238131
#
# outer iteration = 49, mass residue = 0.20356250025125072
# outer iteration = 49, mass residue = 0.14422003761407287
#
# outer iteration = 50, mass residue = 0.18163964626827286
# outer iteration = 50, mass residue = 0.12369633206764089
#
# outer iteration = 51, mass residue = 0.16042974838946883
# outer iteration = 51, mass residue = 0.1052892395720329
#
# outer iteration = 52, mass residue = 0.14044170522178034
# outer iteration = 52, mass residue = 0.08932503245457481
#
# outer iteration = 53, mass residue = 0.12210736011488828
# outer iteration = 53, mass residue = 0.07600028969057683
#
# outer iteration = 54, mass residue = 0.10575872586225751
# outer iteration = 54, mass residue = 0.06537168153861217
#
# outer iteration = 55, mass residue = 0.09161852420871767
# outer iteration = 55, mass residue = 0.05735929169379574
#
# outer iteration = 56, mass residue = 0.07980412250985583
# outer iteration = 56, mass residue = 0.051764522618467645
#
# outer iteration = 57, mass residue = 0.07033853784843033
# outer iteration = 57, mass residue = 0.048298812392579105
#
# outer iteration = 58, mass residue = 0.06315840476485732
# outer iteration = 58, mass residue = 0.04661648818657619
#
# outer iteration = 59, mass residue = 0.05811275178041541
# outer iteration = 59, mass residue = 0.04634485308996552
#
# outer iteration = 60, mass residue = 0.05495791461269141
# outer iteration = 60, mass residue = 0.04710813174844613
#
# outer iteration = 61, mass residue = 0.05336451413773829
# outer iteration = 61, mass residue = 0.04854505914607162
#
# outer iteration = 62, mass residue = 0.05294694489000357
# outer iteration = 62, mass residue = 0.050321884250059415
#
# outer iteration = 63, mass residue = 0.05330753840477309
# outer iteration = 63, mass residue = 0.05214174970290197
#
# outer iteration = 64, mass residue = 0.054076393402137414
# outer iteration = 64, mass residue = 0.05375062541301163
#
# outer iteration = 65, mass residue = 0.0549347823235592
# outer iteration = 65, mass residue = 0.054940077585371554
#
# outer iteration = 66, mass residue = 0.05562267699986252
# outer iteration = 66, mass residue = 0.055547351289178655
#
# outer iteration = 67, mass residue = 0.055936726076028856
# outer iteration = 67, mass residue = 0.05545356332168758
#
# outer iteration = 68, mass residue = 0.05572430492972122
# outer iteration = 68, mass residue = 0.05458075379325516
#
# outer iteration = 69, mass residue = 0.05487794842767423
# outer iteration = 69, mass residue = 0.0528872450344636
#
# outer iteration = 70, mass residue = 0.053328456371476
# outer iteration = 70, mass residue = 0.050365583692098974
#
# outer iteration = 71, mass residue = 0.05104181352239998
# outer iteration = 71, mass residue = 0.047037013550322714
#
# outer iteration = 72, mass residue = 0.04801454987098341
# outer iteration = 72, mass residue = 0.04294773049394896
#
# outer iteration = 73, mass residue = 0.044271131385109096
# outer iteration = 73, mass residue = 0.03816546249870234
#
# outer iteration = 74, mass residue = 0.039862514337498774
# outer iteration = 74, mass residue = 0.03277654618283012
#
# outer iteration = 75, mass residue = 0.03486649346636643
# outer iteration = 75, mass residue = 0.026883551269004234
#
# outer iteration = 76, mass residue = 0.02939156635459793
# outer iteration = 76, mass residue = 0.020603566128145512
#
# outer iteration = 77, mass residue = 0.02358972373634757
# outer iteration = 77, mass residue = 0.01406887435224971
#
# outer iteration = 78, mass residue = 0.017698603547333654
# outer iteration = 78, mass residue = 0.007445501721590809
#
# outer iteration = 79, mass residue = 0.012201987857824639
# outer iteration = 79, mass residue = 0.0016037784706346503
#
# outer iteration = 80, mass residue = 0.008464986536934742
# outer iteration = 80, mass residue = 0.006131063961199958
#
# outer iteration = 81, mass residue = 0.00880814967820967
# outer iteration = 81, mass residue = 0.012217015011008182
#
# outer iteration = 82, mass residue = 0.012783350379712531
# outer iteration = 82, mass residue = 0.017873939576521756
#
# outer iteration = 83, mass residue = 0.017689497327013446
# outer iteration = 83, mass residue = 0.02299317327918519
#
# outer iteration = 84, mass residue = 0.022486913720415027
# outer iteration = 84, mass residue = 0.02751159839290893
#
# outer iteration = 85, mass residue = 0.026848191416041233
# outer iteration = 85, mass residue = 0.03138246648892271
#
# outer iteration = 86, mass residue = 0.03063610519415867
# outer iteration = 86, mass residue = 0.03457409641642587
#
# outer iteration = 87, mass residue = 0.03378303826013787
# outer iteration = 87, mass residue = 0.037071626366809815
#
# outer iteration = 88, mass residue = 0.03625924712623117
# outer iteration = 88, mass residue = 0.03887783547503381
#
# outer iteration = 89, mass residue = 0.03806181047713636
# outer iteration = 89, mass residue = 0.04001284336644405
#
# outer iteration = 90, mass residue = 0.03920923844891884
# outer iteration = 90, mass residue = 0.040512982444443665
#
# outer iteration = 91, mass residue = 0.03973806759068136
# outer iteration = 91, mass residue = 0.04042898903007169
#
# outer iteration = 92, mass residue = 0.03969954420295117
# outer iteration = 92, mass residue = 0.03982361375332438
#
# outer iteration = 93, mass residue = 0.039156530426693065
# outer iteration = 93, mass residue = 0.03876881989435044
#
# outer iteration = 94, mass residue = 0.03818019686732121
# outer iteration = 94, mass residue = 0.03734275268399147
#
# outer iteration = 95, mass residue = 0.03684686094193626
# outer iteration = 95, mass residue = 0.035626545296994674
#
# outer iteration = 96, mass residue = 0.035234796653119405
# outer iteration = 96, mass residue = 0.033701231472056906
#
# outer iteration = 97, mass residue = 0.03342124114172414
# outer iteration = 97, mass residue = 0.03164489575120288
#
# outer iteration = 98, mass residue = 0.03147983034962764
# outer iteration = 98, mass residue = 0.029530118035286157
#
# outer iteration = 99, mass residue = 0.029478376407715553
# outer iteration = 99, mass residue = 0.027421859485197094
#
# outer iteration = 100, mass residue = 0.027477135238283545
# outer iteration = 100, mass residue = 0.025375857004857817
#
# outer iteration = 101, mass residue = 0.025527582164390297
# outer iteration = 101, mass residue = 0.02343756141713611
#
# outer iteration = 102, mass residue = 0.0236716892526506
# outer iteration = 102, mass residue = 0.021641618664363205
#
# outer iteration = 103, mass residue = 0.021941666629721347
# outer iteration = 103, mass residue = 0.02001186047807096
#
# outer iteration = 104, mass residue = 0.020360105510039313
# outer iteration = 104, mass residue = 0.018561748538170105
#
# outer iteration = 105, mass residue = 0.018940449974673833
# outer iteration = 105, mass residue = 0.017295200403119475
#
# outer iteration = 106, mass residue = 0.01768772263409586
# outer iteration = 106, mass residue = 0.01620770769049903
#
# outer iteration = 107, mass residue = 0.01659942874301285
# outer iteration = 107, mass residue = 0.015287660364083522
#
# outer iteration = 108, mass residue = 0.015666586833765383
# outer iteration = 108, mass residue = 0.014517795633045298
#
# outer iteration = 109, mass residue = 0.01487485389125726
# outer iteration = 109, mass residue = 0.013876680692207264
#
# outer iteration = 110, mass residue = 0.014205707767461091
# outer iteration = 110, mass residue = 0.01334016507133321
#
# outer iteration = 111, mass residue = 0.013637669406302223
# outer iteration = 111, mass residue = 0.012882752868775271
#
# outer iteration = 112, mass residue = 0.013147538216814381
# outer iteration = 112, mass residue = 0.012478855185498364
#
# outer iteration = 113, mass residue = 0.012711597041124546
# outer iteration = 113, mass residue = 0.01210389122072409
#
# outer iteration = 114, mass residue = 0.012306731587728112
# outer iteration = 114, mass residue = 0.011735214684203677
#
# outer iteration = 115, mass residue = 0.011911410434594384
# outer iteration = 115, mass residue = 0.011352848908242638
#
# outer iteration = 116, mass residue = 0.011506482484153209
# outer iteration = 116, mass residue = 0.010940025439392887
#
# outer iteration = 117, mass residue = 0.011075770796313333
# outer iteration = 117, mass residue = 0.010483527251681557
#
# outer iteration = 118, mass residue = 0.010606457553319773
# outer iteration = 118, mass residue = 0.009973847909336139
#
# outer iteration = 119, mass residue = 0.010089273169187164
# outer iteration = 119, mass residue = 0.0094051857179512
#
# outer iteration = 120, mass residue = 0.009518527890027233
# outer iteration = 120, mass residue = 0.008775291042860641
#
# outer iteration = 121, mass residue = 0.008891934630553818
# outer iteration = 121, mass residue = 0.008085224046672838
#
# outer iteration = 122, mass residue = 0.008210431929821302
# outer iteration = 122, mass residue = 0.0073389282972989005
#
# outer iteration = 123, mass residue = 0.007477834027401748
# outer iteration = 123, mass residue = 0.0065428799426011704
#
# outer iteration = 124, mass residue = 0.006700498879503807
# outer iteration = 124, mass residue = 0.005705627068792741
#
# outer iteration = 125, mass residue = 0.005887004663516862
# outer iteration = 125, mass residue = 0.004837315003468652
#
# outer iteration = 126, mass residue = 0.005047902896321234
# outer iteration = 126, mass residue = 0.003949227279961275
#
# outer iteration = 127, mass residue = 0.004195722925571851
# outer iteration = 127, mass residue = 0.0030533722005356553
#
# outer iteration = 128, mass residue = 0.003345645281327192
# outer iteration = 128, mass residue = 0.002162187814489989
#
# outer iteration = 129, mass residue = 0.0025182010199389228
# outer iteration = 129, mass residue = 0.0012887935542185184
#
# outer iteration = 130, mass residue = 0.0017495078101585708
# outer iteration = 130, mass residue = 0.0004542806056206016
#
# outer iteration = 131, mass residue = 0.0011347254557209936
# outer iteration = 131, mass residue = 0.00040391054411457095
#
# outer iteration = 132, mass residue = 0.00094118571495032
# outer iteration = 132, mass residue = 0.0011500585334580128
#
# outer iteration = 133, mass residue = 0.0012923906186007989
# outer iteration = 133, mass residue = 0.0018520161022204603
#
# outer iteration = 134, mass residue = 0.0018462457253702533
# outer iteration = 134, mass residue = 0.002492368265757069
#
# outer iteration = 135, mass residue = 0.0024177489422619837
# outer iteration = 135, mass residue = 0.0030654504413180194
#
# outer iteration = 136, mass residue = 0.002953960383091609
# outer iteration = 136, mass residue = 0.0035681130253034697
#
# outer iteration = 137, mass residue = 0.003436411496876349
# outer iteration = 137, mass residue = 0.00399895037938507
#
# outer iteration = 138, mass residue = 0.003857418542537415
# outer iteration = 138, mass residue = 0.004358117231112894
#
# outer iteration = 139, mass residue = 0.004214007304642893
# outer iteration = 139, mass residue = 0.004647208283541818
#
# outer iteration = 140, mass residue = 0.0045059227314919
# outer iteration = 140, mass residue = 0.004869125837551135
#
# outer iteration = 141, mass residue = 0.004734796559601732
# outer iteration = 141, mass residue = 0.005027918166410248
#
# outer iteration = 142, mass residue = 0.004903693033973628
# outer iteration = 142, mass residue = 0.00512858554929942
#
# outer iteration = 143, mass residue = 0.005016785172654496
# outer iteration = 143, mass residue = 0.005176864441140751
#
# outer iteration = 144, mass residue = 0.0050790819346807495
# outer iteration = 144, mass residue = 0.005179000899713114
#
# outer iteration = 145, mass residue = 0.005096179103744466
# outer iteration = 145, mass residue = 0.005141523572286025
#
# outer iteration = 146, mass residue = 0.005074026091371277
# outer iteration = 146, mass residue = 0.005071024084439721
#
# outer iteration = 147, mass residue = 0.005018707280535797
# outer iteration = 147, mass residue = 0.0049739543388094614
#
# outer iteration = 148, mass residue = 0.004936242868959175
# outer iteration = 148, mass residue = 0.004856446101950862
#
# outer iteration = 149, mass residue = 0.004832411804205003
# outer iteration = 149, mass residue = 0.004724158209328763
#
# outer iteration = 150, mass residue = 0.0047126008767457315
# outer iteration = 150, mass residue = 0.004582155583765046
#
# outer iteration = 151, mass residue = 0.004581683434431258
# outer iteration = 151, mass residue = 0.004434821734757373
#
# outer iteration = 152, mass residue = 0.004443929023237361
# outer iteration = 152, mass residue = 0.004285804902924459
#
# outer iteration = 153, mass residue = 0.004302944145337517
# outer iteration = 153, mass residue = 0.004137996747600171
#
# outer iteration = 154, mass residue = 0.004161643272532799
# outer iteration = 154, mass residue = 0.003993541148693596
#
# outer iteration = 155, mass residue = 0.004022248092392194
# outer iteration = 155, mass residue = 0.0038538696005125037
#
# outer iteration = 156, mass residue = 0.0038863120230379464
# outer iteration = 156, mass residue = 0.0037197592022512045
#
# outer iteration = 157, mass residue = 0.003754766658920665
# outer iteration = 157, mass residue = 0.0035914079989170385
#
# outer iteration = 158, mass residue = 0.0036279855771066904
# outer iteration = 158, mass residue = 0.0034685231939784802
#
# outer iteration = 159, mass residue = 0.0035058617368434377
# outer iteration = 159, mass residue = 0.0033504171961031316
#
# outer iteration = 160, mass residue = 0.0033878939504542846
# outer iteration = 160, mass residue = 0.0032361072757118923
#
# outer iteration = 161, mass residue = 0.0032732785920028644
# outer iteration = 161, mass residue = 0.0031244145089447052
#
# outer iteration = 162, mass residue = 0.0031610023389571796
# outer iteration = 162, mass residue = 0.0030140582104824084
#
# outer iteration = 163, mass residue = 0.003049932156140888
# outer iteration = 163, mass residue = 0.0029037429594942084
#
# outer iteration = 164, mass residue = 0.002938899480955713
# outer iteration = 164, mass residue = 0.0027922356747702654
#
# outer iteration = 165, mass residue = 0.002826775818428206
# outer iteration = 165, mass residue = 0.0026784309420510547
#
# outer iteration = 166, mass residue = 0.0027125376934193112
# outer iteration = 166, mass residue = 0.0025614034971816234
#
# outer iteration = 167, mass residue = 0.002595319643755883
# outer iteration = 167, mass residue = 0.002440446991343935
#
# outer iteration = 168, mass residue = 0.002474454179568679
# outer iteration = 168, mass residue = 0.002315099189106144
#
# outer iteration = 169, mass residue = 0.002349498728136543
# outer iteration = 169, mass residue = 0.002185153912584518
#
# outer iteration = 170, mass residue = 0.0022202497901708854
# outer iteration = 170, mass residue = 0.002050660850921586
#
# outer iteration = 171, mass residue = 0.002086745366916532
# outer iteration = 171, mass residue = 0.0019119146366485113
#
# outer iteration = 172, mass residue = 0.0019492570039440521
# outer iteration = 172, mass residue = 0.0017694347283348497
#
# outer iteration = 173, mass residue = 0.0018082729583986535
# outer iteration = 173, mass residue = 0.0016239377692071038
#
# outer iteration = 174, mass residue = 0.001664474173107378
# outer iteration = 174, mass residue = 0.001476304846209558
#
# outer iteration = 175, mass residue = 0.001518705563851198
# outer iteration = 175, mass residue = 0.0013275447772676892
#
# outer iteration = 176, mass residue = 0.0013719439158406583
# outer iteration = 176, mass residue = 0.001178755269017538
#
# outer iteration = 177, mass residue = 0.0012252640935837412
# outer iteration = 177, mass residue = 0.0010310847761178703
#
# outer iteration = 178, mass residue = 0.0010798106289478609
# outer iteration = 178, mass residue = 0.0008856925947990109
#
# outer iteration = 179, mass residue = 0.0009367674406579842
# outer iteration = 179, mass residue = 0.0007437146286626487
#
# outer iteration = 180, mass residue = 0.0007973429234250631
# outer iteration = 180, mass residue = 0.000606231470782053
#
# outer iteration = 181, mass residue = 0.0006627761600201341
# outer iteration = 181, mass residue = 0.0004742409520129813
#
# outer iteration = 182, mass residue = 0.0005343893592564254
# outer iteration = 182, mass residue = 0.00034863750282431046
#
# outer iteration = 183, mass residue = 0.0004137604581295082
# outer iteration = 183, mass residue = 0.00023020498064569265
#
# outer iteration = 184, mass residue = 0.00030325636990269583
# outer iteration = 184, mass residue = 0.00011967610696714221
#
# outer iteration = 185, mass residue = 0.00020784701122920703
# outer iteration = 185, mass residue = 2.004138552732106e-05
#
# outer iteration = 186, mass residue = 0.00014138619676406494
# outer iteration = 186, mass residue = 7.824561387756242e-05
#
# outer iteration = 187, mass residue = 0.00013173363748126264
# outer iteration = 187, mass residue = 0.00016312913297423904
#
# outer iteration = 188, mass residue = 0.00017481047911158904
# outer iteration = 188, mass residue = 0.00023963115573000094
#
# outer iteration = 189, mass residue = 0.00023512994001757484
# outer iteration = 189, mass residue = 0.00030764379912894625
#
# outer iteration = 190, mass residue = 0.0002960032262555023
# outer iteration = 190, mass residue = 0.00036735124508922737
#
# outer iteration = 191, mass residue = 0.0003523907578975069
# outer iteration = 191, mass residue = 0.00041906512607359106
#
# outer iteration = 192, mass residue = 0.0004027144127041264
# outer iteration = 192, mass residue = 0.0004631925749257539
#
# outer iteration = 193, mass residue = 0.00044655443765604475
# outer iteration = 193, mass residue = 0.0005002150109806694
#
# outer iteration = 194, mass residue = 0.0004839690847610903
# outer iteration = 194, mass residue = 0.000530667644361563
#
# outer iteration = 195, mass residue = 0.0005152481324631352
# outer iteration = 195, mass residue = 0.000555119742203747
#
# outer iteration = 196, mass residue = 0.0005408037830283109
# outer iteration = 196, mass residue = 0.0005741564074482677
#
# outer iteration = 197, mass residue = 0.0005611129528046576
# outer iteration = 197, mass residue = 0.0005883616574238616
#
# outer iteration = 198, mass residue = 0.000576681261675774
# outer iteration = 198, mass residue = 0.0005983035253939365
#
# outer iteration = 199, mass residue = 0.0005880182723767688
# outer iteration = 199, mass residue = 0.0006045215712530899
#
# outer iteration = 200, mass residue = 0.000595619541450068
# outer iteration = 200, mass residue = 0.0006075166496956327
#
# outer iteration = 201, mass residue = 0.000599953120481853
# outer iteration = 201, mass residue = 0.0006077432281550119
#
# outer iteration = 202, mass residue = 0.0006014497810720822
# outer iteration = 202, mass residue = 0.0006056041208627503
#
# outer iteration = 203, mass residue = 0.000600496231151126
# outer iteration = 203, mass residue = 0.0006014476844507547
#
# outer iteration = 204, mass residue = 0.0005974311265364342
# outer iteration = 204, mass residue = 0.0005955672704155528
#
# outer iteration = 205, mass residue = 0.000592543496723826
# outer iteration = 205, mass residue = 0.0005882026616914509
#
# outer iteration = 206, mass residue = 0.0005860732420394127
# outer iteration = 206, mass residue = 0.0005795432662327527
#
# outer iteration = 207, mass residue = 0.0005782134466625032
# outer iteration = 207, mass residue = 0.0005697327195109443
#
# outer iteration = 208, mass residue = 0.0005691141510236429
# outer iteration = 208, mass residue = 0.0005588745679838264
#
# outer iteration = 209, mass residue = 0.0005588872647102207
# outer iteration = 209, mass residue = 0.0005470386941603529
#
# outer iteration = 210, mass residue = 0.0005476122889572432
# outer iteration = 210, mass residue = 0.0005342681948194854
#
# outer iteration = 211, mass residue = 0.000535342570738819
# outer iteration = 211, mass residue = 0.0005205863922681709
#
# outer iteration = 212, mass residue = 0.0005221117720478787
# outer iteration = 212, mass residue = 0.0005060036798454664
#
# outer iteration = 213, mass residue = 0.0005079402607035198
# outer iteration = 213, mass residue = 0.0004905239691329186
#
# outer iteration = 214, mass residue = 0.0004928411918781201
# outer iteration = 214, mass residue = 0.00047415051074090866
#
# outer iteration = 215, mass residue = 0.000476826048455926
# outer iteration = 215, mass residue = 0.00045689098484265035
#
# outer iteration = 216, mass residue = 0.0004599095420883945
# outer iteration = 216, mass residue = 0.0004387616287461556
#
# outer iteration = 217, mass residue = 0.00044211361609932173
# outer iteration = 217, mass residue = 0.00041979046428600327
#
# outer iteration = 218, mass residue = 0.0004234706360705834
# outer iteration = 218, mass residue = 0.0004000194751529517
#
# outer iteration = 219, mass residue = 0.0004040255804646873
# outer iteration = 219, mass residue = 0.00037950589867941884
#
# outer iteration = 220, mass residue = 0.00038383742264754873
# outer iteration = 220, mass residue = 0.0003583225740125935
#
# outer iteration = 221, mass residue = 0.00036297960136285137
# outer iteration = 221, mass residue = 0.00033655744184575516
#
# outer iteration = 222, mass residue = 0.0003415396866335153
# outer iteration = 222, mass residue = 0.00031431234926596654
#
# outer iteration = 223, mass residue = 0.00031961840081737053
# outer iteration = 223, mass residue = 0.00029170118180430203
#
# outer iteration = 224, mass residue = 0.0002973279869646286
# outer iteration = 224, mass residue = 0.0002688475810477584
#
# outer iteration = 225, mass residue = 0.0002747902054679039
# outer iteration = 225, mass residue = 0.0002458823040398207
#
# outer iteration = 226, mass residue = 0.00025213400587563125
# outer iteration = 226, mass residue = 0.00022294035270741317
#
# outer iteration = 227, mass residue = 0.00022949301291733516
# outer iteration = 227, mass residue = 0.0002001579895482796
#
# outer iteration = 228, mass residue = 0.0002070029843795433
# outer iteration = 228, mass residue = 0.00017766985530432482
#
# outer iteration = 229, mass residue = 0.0001847995077431953
# outer iteration = 229, mass residue = 0.0001556061950382595
#
# outer iteration = 230, mass residue = 0.0001630160367812644
# outer iteration = 230, mass residue = 0.00013409030717038436
#
# outer iteration = 231, mass residue = 0.000141782634638762
# outer iteration = 231, mass residue = 0.00011323631760424889
#
# outer iteration = 232, mass residue = 0.00012122604554370651
# outer iteration = 232, mass residue = 9.31471882470912e-05
#
# outer iteration = 233, mass residue = 0.00010147167209003275
# outer iteration = 233, mass residue = 7.391356211867535e-05
#
# outer iteration = 234, mass residue = 8.265178912598501e-05
# outer iteration = 234, mass residue = 5.5613016899410464e-05
#
# outer iteration = 235, mass residue = 6.492550863976132e-05
# outer iteration = 235, mass residue = 3.8310725398006844e-05
#
# outer iteration = 236, mass residue = 4.853585782566425e-05
# outer iteration = 236, mass residue = 2.206621383031937e-05
#
# outer iteration = 237, mass residue = 3.3993123748480516e-05
# outer iteration = 237, mass residue = 7.027406854377647e-06
#
# outer iteration = 238, mass residue = 2.2735344077397845e-05
# outer iteration = 238, mass residue = 7.554297183409768e-06
#
# outer iteration = 239, mass residue = 1.8551791203641303e-05
# outer iteration = 239, mass residue = 2.0428744253484418e-05
#
# outer iteration = 240, mass residue = 2.3397759277139466e-05
# outer iteration = 240, mass residue = 3.232496183521339e-05
#
# outer iteration = 241, mass residue = 3.225429194443883e-05
# outer iteration = 241, mass residue = 4.316294177529025e-05
#
# outer iteration = 242, mass residue = 4.178669640801066e-05
# outer iteration = 242, mass residue = 5.2960243292981784e-05
#
# outer iteration = 243, mass residue = 5.096437993724927e-05
# outer iteration = 243, mass residue = 6.175185784577507e-05
#
# outer iteration = 244, mass residue = 5.946472652563439e-05
# outer iteration = 244, mass residue = 6.958083750476639e-05
#
# outer iteration = 245, mass residue = 6.718239734183056e-05
# outer iteration = 245, mass residue = 7.649542282336698e-05
#
# outer iteration = 246, mass residue = 7.409330837638123e-05
# outer iteration = 246, mass residue = 8.254700769086183e-05
#
# outer iteration = 247, mass residue = 8.020900362403524e-05
# outer iteration = 247, mass residue = 8.778870427190496e-05
#
# outer iteration = 248, mass residue = 8.555850079919517e-05
# outer iteration = 248, mass residue = 9.227392689416114e-05
#
# outer iteration = 249, mass residue = 9.01795754584808e-05
# outer iteration = 249, mass residue = 9.605524256362203e-05
#
# outer iteration = 250, mass residue = 9.41141069644377e-05
# outer iteration = 250, mass residue = 9.918356730804531e-05
#
# outer iteration = 251, mass residue = 9.740546130154448e-05
# outer iteration = 251, mass residue = 0.00010170741771848042
#
# outer iteration = 252, mass residue = 0.0001000967095751335
# outer iteration = 252, mass residue = 0.0001036723448394162
#
# outer iteration = 253, mass residue = 0.0001022294494541624
# outer iteration = 253, mass residue = 0.00010512055143053303
#
# outer iteration = 254, mass residue = 0.000103843036472014
# outer iteration = 254, mass residue = 0.00010609068023280251
#
# outer iteration = 255, mass residue = 0.00010497411202847725
# outer iteration = 255, mass residue = 0.00010661777393748873
#
# outer iteration = 256, mass residue = 0.00010565637713037782
# outer iteration = 256, mass residue = 0.00010673337829594236
#
# outer iteration = 257, mass residue = 0.00010592055371919379
# outer iteration = 257, mass residue = 0.00010646570783600887
#
# outer iteration = 258, mass residue = 0.00010579443386519572
# outer iteration = 258, mass residue = 0.0001058399934338093
#
# outer iteration = 259, mass residue = 0.00010530313767792554
# outer iteration = 259, mass residue = 0.00010487886795252938
#
# outer iteration = 260, mass residue = 0.00010446941701417247
# outer iteration = 260, mass residue = 0.00010360279678202813
#
# outer iteration = 261, mass residue = 0.00010331401764396872
# outer iteration = 261, mass residue = 0.00010203054201186829
#
# outer iteration = 262, mass residue = 0.00010185608646533634
# outer iteration = 262, mass residue = 0.00010017962393423424
#
# outer iteration = 263, mass residue = 0.00010011358298695481
# outer iteration = 263, mass residue = 9.806675917157807e-05
#
# outer iteration = 264, mass residue = 9.810367586354978e-05
# outer iteration = 264, mass residue = 9.570825829369298e-05
#
# outer iteration = 265, mass residue = 9.584310847875374e-05
# outer iteration = 265, mass residue = 9.312037953826177e-05
#
# outer iteration = 266, mass residue = 9.334852841588357e-05
# outer iteration = 266, mass residue = 9.031962412731428e-05
#
# outer iteration = 267, mass residue = 9.063676637095636e-05
# outer iteration = 267, mass residue = 8.732295303879524e-05
#
# outer iteration = 268, mass residue = 8.772503946458765e-05
# outer iteration = 268, mass residue = 8.414794621940763e-05
#
# outer iteration = 269, mass residue = 8.463110808398777e-05
# outer iteration = 269, mass residue = 8.081290158828963e-05
#
# outer iteration = 270, mass residue = 8.137337566434453e-05
# outer iteration = 270, mass residue = 7.733685621933406e-05
#
# outer iteration = 271, mass residue = 7.797091241184359e-05
# outer iteration = 271, mass residue = 7.373954774992073e-05
#
# outer iteration = 272, mass residue = 7.444342501601252e-05
# outer iteration = 272, mass residue = 7.004131282068926e-05
#
# outer iteration = 273, mass residue = 7.081116624369235e-05
# outer iteration = 273, mass residue = 6.626294359496453e-05
#
# outer iteration = 274, mass residue = 6.709480500325227e-05
# outer iteration = 274, mass residue = 6.242550333295126e-05
#
# outer iteration = 275, mass residue = 6.331525871057006e-05
# outer iteration = 275, mass residue = 5.855011921781623e-05
#
# outer iteration = 276, mass residue = 5.949350074466165e-05
# outer iteration = 276, mass residue = 5.465774708728439e-05
#
# outer iteration = 277, mass residue = 5.565034334297919e-05
# outer iteration = 277, mass residue = 5.07689299473432e-05
#
# outer iteration = 278, mass residue = 5.18062124711124e-05
# outer iteration = 278, mass residue = 4.69035536049113e-05
#
# outer iteration = 279, mass residue = 4.7980921680775976e-05
# outer iteration = 279, mass residue = 4.3080619883794124e-05
#
# outer iteration = 280, mass residue = 4.419346426521346e-05
# outer iteration = 280, mass residue = 3.9318024227388276e-05
#
# outer iteration = 281, mass residue = 4.0461808951677425e-05
# outer iteration = 281, mass residue = 3.5632365367297805e-05
#
# outer iteration = 282, mass residue = 3.6802732630670985e-05
# outer iteration = 282, mass residue = 3.2038789236357977e-05
#
# outer iteration = 283, mass residue = 3.323169077077808e-05
# outer iteration = 283, mass residue = 2.8550861795513193e-05
#
# outer iteration = 284, mass residue = 2.976272493389195e-05
# outer iteration = 284, mass residue = 2.5180485433251812e-05
#
# outer iteration = 285, mass residue = 2.6408431894962755e-05
# outer iteration = 285, mass residue = 2.193784275182475e-05
#
# outer iteration = 286, mass residue = 2.3179988839838248e-05
# outer iteration = 286, mass residue = 1.883138183348623e-05
#
# outer iteration = 287, mass residue = 2.0087280019860217e-05
# outer iteration = 287, mass residue = 1.586784980713405e-05
#
# outer iteration = 288, mass residue = 1.7139185457236363e-05
# outer iteration = 288, mass residue = 1.3052346721688323e-05
#
# outer iteration = 289, mass residue = 1.4344127808371617e-05
# outer iteration = 289, mass residue = 1.0388426487723255e-05
#
# outer iteration = 290, mass residue = 1.1711197810395066e-05
# outer iteration = 290, mass residue = 7.87825803187718e-06
#
# outer iteration = 291, mass residue = 9.25272863244941e-06
# outer iteration = 291, mass residue = 5.5228849349003925e-06
#
# outer iteration = 292, mass residue = 6.9907008737095535e-06
# outer iteration = 292, mass residue = 3.3230392966116667e-06
#
# outer iteration = 293, mass residue = 4.976057481182765e-06
# outer iteration = 293, mass residue = 1.2860865515429825e-06
#
# outer iteration = 294, mass residue = 3.35550873671837e-06
# outer iteration = 294, mass residue = 6.854347909383884e-07
#
# outer iteration = 295, mass residue = 2.5481254688804707e-06
# outer iteration = 295, mass residue = 2.4086467040092853e-06
#
# outer iteration = 296, mass residue = 2.9549886813215295e-06
# outer iteration = 296, mass residue = 4.018127509140328e-06
#
# outer iteration = 297, mass residue = 4.059502493643098e-06
# outer iteration = 297, mass residue = 5.493823332669044e-06
#
# outer iteration = 298, mass residue = 5.327709692791418e-06
# outer iteration = 298, mass residue = 6.838266999694663e-06
#
# outer iteration = 299, mass residue = 6.576961931976918e-06
# outer iteration = 299, mass residue = 8.05563179348773e-06
#
# outer iteration = 300, mass residue = 7.750018194367501e-06
# outer iteration = 300, mass residue = 9.150561148654635e-06
#
# outer iteration = 301, mass residue = 8.827217758240342e-06
# outer iteration = 301, mass residue = 1.012790564197856e-05
#
# outer iteration = 302, mass residue = 9.80212163400636e-06
# outer iteration = 302, mass residue = 1.0992600864152071e-05
#
# outer iteration = 303, mass residue = 1.0673741357775607e-05
# outer iteration = 303, mass residue = 1.1749584153949967e-05
#
# outer iteration = 304, mass residue = 1.1443605997460402e-05
# outer iteration = 304, mass residue = 1.2403742872309624e-05
#
# outer iteration = 305, mass residue = 1.2114500992502808e-05
# outer iteration = 305, mass residue = 1.2959866511395312e-05
#
# outer iteration = 306, mass residue = 1.2689849012491716e-05
# outer iteration = 306, mass residue = 1.3422620296880517e-05
#
# outer iteration = 307, mass residue = 1.3173391089235653e-05
# outer iteration = 307, mass residue = 1.3796534099346723e-05
#
# outer iteration = 308, mass residue = 1.3569014512930883e-05
# outer iteration = 308, mass residue = 1.4086002404253498e-05
#
# outer iteration = 309, mass residue = 1.3880658193831395e-05
# outer iteration = 309, mass residue = 1.4295293505095392e-05
#
# outer iteration = 310, mass residue = 1.4112263238737909e-05
# outer iteration = 310, mass residue = 1.4428564868010607e-05
#
# outer iteration = 311, mass residue = 1.4267750131612227e-05
# outer iteration = 311, mass residue = 1.4489882532642397e-05
#
# outer iteration = 312, mass residue = 1.4351012193239752e-05
# outer iteration = 312, mass residue = 1.4483241688309824e-05
#
# outer iteration = 313, mass residue = 1.4365917926951531e-05
# outer iteration = 313, mass residue = 1.4412587805334795e-05
#
# outer iteration = 314, mass residue = 1.4316319102184782e-05
# outer iteration = 314, mass residue = 1.428183606072816e-05
#
# outer iteration = 315, mass residue = 1.4206060541914573e-05
# outer iteration = 315, mass residue = 1.4094888292027717e-05
#
# outer iteration = 316, mass residue = 1.403899001020652e-05
# outer iteration = 316, mass residue = 1.3855645400074598e-05
#
# outer iteration = 317, mass residue = 1.3818965420447824e-05
# outer iteration = 317, mass residue = 1.356801599741162e-05
#
# outer iteration = 318, mass residue = 1.354985978710546e-05
# outer iteration = 318, mass residue = 1.3235920085389725e-05
#
# outer iteration = 319, mass residue = 1.323556229576621e-05
# outer iteration = 319, mass residue = 1.286328883354261e-05
#
# outer iteration = 320, mass residue = 1.2879976460232263e-05
# outer iteration = 320, mass residue = 1.2454060033715147e-05
#
# outer iteration = 321, mass residue = 1.2487014595574331e-05
# outer iteration = 321, mass residue = 1.201216787949995e-05
#
# outer iteration = 322, mass residue = 1.2060587031870982e-05
# outer iteration = 322, mass residue = 1.1541529598341472e-05
#
# outer iteration = 323, mass residue = 1.1604588914083899e-05
# outer iteration = 323, mass residue = 1.104603125780298e-05
#
# outer iteration = 324, mass residue = 1.112288651419676e-05
# outer iteration = 324, mass residue = 1.052950780143891e-05
#
# outer iteration = 325, mass residue = 1.0619297555003492e-05
# outer iteration = 325, mass residue = 9.995718577556716e-06
#
# outer iteration = 326, mass residue = 1.0097567626876297e-05
# outer iteration = 326, mass residue = 9.448326126616006e-06
#
# outer iteration = 327, mass residue = 9.561350389796412e-06
# outer iteration = 327, mass residue = 8.890880598025181e-06
#
# outer iteration = 328, mass residue = 9.014193457109987e-06
# outer iteration = 328, mass residue = 8.32679253930449e-06
#
# outer iteration = 329, mass residue = 8.459511131712093e-06
# outer iteration = 329, mass residue = 7.759313745840138e-06
#
# outer iteration = 330, mass residue = 7.900567291810465e-06
# outer iteration = 330, mass residue = 7.191514382659173e-06
#
# outer iteration = 331, mass residue = 7.340453451080061e-06
# outer iteration = 331, mass residue = 6.626273465843911e-06
#
# outer iteration = 332, mass residue = 6.782082143613458e-06
# outer iteration = 332, mass residue = 6.0662652406257074e-06
#
# outer iteration = 333, mass residue = 6.228174407062552e-06
# outer iteration = 333, mass residue = 5.513947920490756e-06
#
# outer iteration = 334, mass residue = 5.681251264285739e-06
# outer iteration = 334, mass residue = 4.971559124782676e-06
#
# outer iteration = 335, mass residue = 5.143633174548602e-06
# outer iteration = 335, mass residue = 4.441114238037917e-06
#
# outer iteration = 336, mass residue = 4.617444448139905e-06
# outer iteration = 336, mass residue = 3.924404341499722e-06
#
# outer iteration = 337, mass residue = 4.1046209746983165e-06
# outer iteration = 337, mass residue = 3.422999964421859e-06
#
# outer iteration = 338, mass residue = 3.60693079099235e-06
# outer iteration = 338, mass residue = 2.93825785830393e-06
#
# outer iteration = 339, mass residue = 3.126010487031072e-06
# outer iteration = 339, mass residue = 2.4713278737948245e-06
#
# outer iteration = 340, mass residue = 2.663428651438149e-06
# outer iteration = 340, mass residue = 2.023171870831427e-06
#
# outer iteration = 341, mass residue = 2.2208164680422627e-06
# outer iteration = 341, mass residue = 1.594573907685351e-06
#
# outer iteration = 342, mass residue = 1.8001156813753056e-06
# outer iteration = 342, mass residue = 1.186167613936102e-06
#
# outer iteration = 343, mass residue = 1.4042106910614624e-06
# outer iteration = 343, mass residue = 7.985056877808898e-07
#
# outer iteration = 344, mass residue = 1.0386638498361307e-06
# outer iteration = 344, mass residue = 4.323686703770042e-07
#
# outer iteration = 345, mass residue = 7.174640338389612e-07
# outer iteration = 345, mass residue = 9.561440964124502e-08
#
# outer iteration = 346, mass residue = 4.840531080597874e-07
# outer iteration = 346, mass residue = 2.4630276602487614e-07
#
# outer iteration = 347, mass residue = 4.410398481498466e-07
# outer iteration = 347, mass residue = 5.480850439497939e-07
#
# outer iteration = 348, mass residue = 5.952371479566637e-07
# outer iteration = 348, mass residue = 8.304463293579904e-07
#
# outer iteration = 349, mass residue = 8.211192012194942e-07
# outer iteration = 349, mass residue = 1.0922260975715372e-06
#
# outer iteration = 350, mass residue = 1.057682183205004e-06
# outer iteration = 350, mass residue = 1.3335837479914784e-06
#
# outer iteration = 351, mass residue = 1.2866338922334436e-06
# outer iteration = 351, mass residue = 1.5549011290614155e-06
#
# outer iteration = 352, mass residue = 1.5018381521229736e-06
# outer iteration = 352, mass residue = 1.7566378737932153e-06
#
# outer iteration = 353, mass residue = 1.70096900047752e-06
# outer iteration = 353, mass residue = 1.939292718196935e-06
#
# outer iteration = 354, mass residue = 1.883148186259851e-06
# outer iteration = 354, mass residue = 2.1033916182256724e-06
#
# outer iteration = 355, mass residue = 2.0481435966971874e-06
# outer iteration = 355, mass residue = 2.2494832149119535e-06
#
# outer iteration = 356, mass residue = 2.1960512405180722e-06
# outer iteration = 356, mass residue = 2.378136192301588e-06
#
# outer iteration = 357, mass residue = 2.3271518889850713e-06
# outer iteration = 357, mass residue = 2.489937021519977e-06
#
# outer iteration = 358, mass residue = 2.4418393276316656e-06
# outer iteration = 358, mass residue = 2.5854888236482075e-06
#
# outer iteration = 359, mass residue = 2.540582152845047e-06
# outer iteration = 359, mass residue = 2.6654098672972554e-06
#
# outer iteration = 360, mass residue = 2.6239014559929927e-06
# outer iteration = 360, mass residue = 2.7303319782859788e-06
#
# outer iteration = 361, mass residue = 2.6923567790830608e-06
# outer iteration = 361, mass residue = 2.7808994006217695e-06
#
# outer iteration = 362, mass residue = 2.7465371888645815e-06
# outer iteration = 362, mass residue = 2.817767758199964e-06
#
# outer iteration = 363, mass residue = 2.78705525983983e-06
# outer iteration = 363, mass residue = 2.8416030651628307e-06
#
# outer iteration = 364, mass residue = 2.8145427603177255e-06
# outer iteration = 364, mass residue = 2.8530806375211724e-06
#
# outer iteration = 365, mass residue = 2.8296472787909557e-06
# outer iteration = 365, mass residue = 2.8528838593581804e-06
#
# outer iteration = 366, mass residue = 2.83302938700278e-06
# outer iteration = 366, mass residue = 2.8417028255518655e-06
#
# outer iteration = 367, mass residue = 2.8253601455747947e-06
# outer iteration = 367, mass residue = 2.8202328092619437e-06
#
# outer iteration = 368, mass residue = 2.8073187458583124e-06
# outer iteration = 368, mass residue = 2.7891725211840222e-06
#
# outer iteration = 369, mass residue = 2.7795901669096403e-06
# outer iteration = 369, mass residue = 2.7492220806577778e-06
#
# outer iteration = 370, mass residue = 2.7428627141662667e-06
# outer iteration = 370, mass residue = 2.7010808231197864e-06
#
# outer iteration = 371, mass residue = 2.697825519025737e-06
# outer iteration = 371, mass residue = 2.645444953675981e-06
#
# outer iteration = 372, mass residue = 2.645165974815231e-06
# outer iteration = 372, mass residue = 2.5830051599588238e-06
#
# outer iteration = 373, mass residue = 2.585567195509091e-06
# outer iteration = 373, mass residue = 2.51444391166594e-06
#
# outer iteration = 374, mass residue = 2.5197052181822945e-06
# outer iteration = 374, mass residue = 2.4404328049726144e-06
#
# outer iteration = 375, mass residue = 2.4482462774355585e-06
# outer iteration = 375, mass residue = 2.361629929436957e-06
#
# outer iteration = 376, mass residue = 2.371844131914944e-06
# outer iteration = 376, mass residue = 2.2786772165544362e-06
#
# outer iteration = 377, mass residue = 2.2911373759989823e-06
# outer iteration = 377, mass residue = 2.1921979625781406e-06
#
# outer iteration = 378, mass residue = 2.2067469718796596e-06
# outer iteration = 378, mass residue = 2.102794536856082e-06
#
# outer iteration = 379, mass residue = 2.119273943594975e-06
# outer iteration = 379, mass residue = 2.011046256849634e-06
#
# outer iteration = 380, mass residue = 2.0292972380387167e-06
# outer iteration = 380, mass residue = 1.917507568107071e-06
#
# outer iteration = 381, mass residue = 1.937371890918894e-06
# outer iteration = 381, mass residue = 1.8227064486701062e-06
#
# outer iteration = 382, mass residue = 1.8440274019185655e-06
# outer iteration = 382, mass residue = 1.727143043863062e-06
#
# outer iteration = 383, mass residue = 1.7497663298543173e-06
# outer iteration = 383, mass residue = 1.6312884144639164e-06
#
# outer iteration = 384, mass residue = 1.655063017706967e-06
# outer iteration = 384, mass residue = 1.535583555824316e-06
#
# outer iteration = 385, mass residue = 1.5603625855927298e-06
# outer iteration = 385, mass residue = 1.4404387198207277e-06
#
# outer iteration = 386, mass residue = 1.4660802242355534e-06
# outer iteration = 386, mass residue = 1.3462329057348406e-06
#
# outer iteration = 387, mass residue = 1.3726006783236995e-06
# outer iteration = 387, mass residue = 1.2533136772065484e-06
#
# outer iteration = 388, mass residue = 1.2802780547446405e-06
# outer iteration = 388, mass residue = 1.1619973047985636e-06
#
# outer iteration = 389, mass residue = 1.1894359375085103e-06
# outer iteration = 389, mass residue = 1.072568952801551e-06
#
# outer iteration = 390, mass residue = 1.1003675882904292e-06
# outer iteration = 390, mass residue = 9.852831487170735e-07
#
# outer iteration = 391, mass residue = 1.013336455466218e-06
# outer iteration = 391, mass residue = 9.003644981678711e-07
#
# outer iteration = 392, mass residue = 9.285769751027755e-07
# outer iteration = 392, mass residue = 8.180087359513655e-07
#
# outer iteration = 393, mass residue = 8.462957700412448e-07
# outer iteration = 393, mass residue = 7.383840382428722e-07
#
# outer iteration = 394, mass residue = 7.666731869485471e-07
# outer iteration = 394, mass residue = 6.616325379054848e-07
#
# outer iteration = 395, mass residue = 6.898651238431996e-07
# outer iteration = 395, mass residue = 5.878719224701883e-07
#
# outer iteration = 396, mass residue = 6.160051837789978e-07
# outer iteration = 396, mass residue = 5.171968155339912e-07
#
# outer iteration = 397, mass residue = 5.452070807692843e-07
# outer iteration = 397, mass residue = 4.4968038146662017e-07
#
# outer iteration = 398, mass residue = 4.775679413253249e-07
# outer iteration = 398, mass residue = 3.8537642881150223e-07
#
# outer iteration = 399, mass residue = 4.1317316721490405e-07
# outer iteration = 399, mass residue = 3.243210338236623e-07
#
# outer iteration = 400, mass residue = 3.5210335786701767e-07
# outer iteration = 400, mass residue = 2.665345552163952e-07
#
# outer iteration = 401, mass residue = 2.9444610861605533e-07
# outer iteration = 401, mass residue = 2.120237357703416e-07
#
# outer iteration = 402, mass residue = 2.4031971126866745e-07
# ...
#
# outer iteration = 870, mass residue = 1.7365200622623134e-12
# outer iteration = 870, mass residue = 1.8421918222654525e-12
#
# outer iteration = 871, mass residue = 1.827518002493279e-12
# outer iteration = 871, mass residue = 1.927754685333082e-12
#
# outer iteration = 872, mass residue = 1.9137201145295625e-12
# outer iteration = 872, mass residue = 2.0085708000200788e-12
#
# outer iteration = 873, mass residue = 1.9952252728734962e-12
# outer iteration = 873, mass residue = 2.0851015986895716e-12
#
# outer iteration = 874, mass residue = 2.0725371815328188e-12
# outer iteration = 874, mass residue = 2.157158293417647e-12
#
# outer iteration = 875, mass residue = 2.145315837456065e-12
# outer iteration = 875, mass residue = 2.225006087672277e-12
#
# outer iteration = 876, mass residue = 2.213941919037752e-12
# outer iteration = 876, mass residue = 2.2888844585261993e-12
#
# outer iteration = 877, mass residue = 2.278616987253783e-12
# outer iteration = 877, mass residue = 2.349077468631871e-12
#
# outer iteration = 878, mass residue = 2.3396084822120047e-12
# outer iteration = 878, mass residue = 2.4053577780068707e-12
#
# outer iteration = 879, mass residue = 2.396620284671938e-12
# outer iteration = 879, mass residue = 2.4580980597539125e-12
#
# outer iteration = 880, mass residue = 2.4501379660420527e-12
# outer iteration = 880, mass residue = 2.507262956170834e-12
#
# outer iteration = 881, mass residue = 2.5000381728829916e-12
# outer iteration = 881, mass residue = 2.5533338949642955e-12
#
# outer iteration = 882, mass residue = 2.5468888912011155e-12
# outer iteration = 882, mass residue = 2.5961399977918134e-12
#
# outer iteration = 883, mass residue = 2.590385745262623e-12
# outer iteration = 883, mass residue = 2.6358144149386783e-12
#
# outer iteration = 884, mass residue = 2.6307513966222603e-12
# outer iteration = 884, mass residue = 2.672681357701559e-12
#
# outer iteration = 885, mass residue = 2.668320329662917e-12
# outer iteration = 885, mass residue = 2.7066243775380516e-12
#
# outer iteration = 886, mass residue = 2.7028992357081665e-12
# outer iteration = 886, mass residue = 2.737866413335205e-12
#
# outer iteration = 887, mass residue = 2.734786266354004e-12
# outer iteration = 887, mass residue = 2.7666437472749586e-12
#
# outer iteration = 888, mass residue = 2.7641978803775685e-12
# outer iteration = 888, mass residue = 2.7927782134482942e-12
#
# outer iteration = 889, mass residue = 2.790893224458546e-12
# outer iteration = 889, mass residue = 2.8164949295407166e-12
#
# outer iteration = 890, mass residue = 2.815189683069179e-12
# outer iteration = 890, mass residue = 2.8378670406449777e-12
#
# outer iteration = 891, mass residue = 2.8371144466031363e-12
# outer iteration = 891, mass residue = 2.8568926806663066e-12
#
# outer iteration = 892, mass residue = 2.8566581706676547e-12
# outer iteration = 892, mass residue = 2.8738027130569733e-12
#
# outer iteration = 893, mass residue = 2.8740947526687495e-12
# outer iteration = 893, mass residue = 2.8884953575572786e-12
#
# outer iteration = 894, mass residue = 2.8892649604572498e-12
# outer iteration = 894, mass residue = 2.901172960584691e-12
#
# outer iteration = 895, mass residue = 2.9024302762308572e-12
# outer iteration = 895, mass residue = 2.911723503150256e-12
#
# outer iteration = 896, mass residue = 2.913423207428495e-12
# outer iteration = 896, mass residue = 2.9204128713894383e-12
#
# outer iteration = 897, mass residue = 2.922576015570115e-12
# outer iteration = 897, mass residue = 2.927167059642118e-12
#
# outer iteration = 898, mass residue = 2.929750623369638e-12
# outer iteration = 898, mass residue = 2.932143739056994e-12
#
# outer iteration = 899, mass residue = 2.9351510994891096e-12
# outer iteration = 899, mass residue = 2.935315297653079e-12
#
# outer iteration = 900, mass residue = 2.9387169644075125e-12
# outer iteration = 900, mass residue = 2.9367291570349462e-12
#
# outer iteration = 901, mass residue = 2.940516406542133e-12
# outer iteration = 901, mass residue = 2.936517655782688e-12
#
# outer iteration = 902, mass residue = 2.940686999066021e-12
# outer iteration = 902, mass residue = 2.9347592224261716e-12
#
# outer iteration = 903, mass residue = 2.9392959215830525e-12
# outer iteration = 903, mass residue = 2.931347374682274e-12
#
# outer iteration = 904, mass residue = 2.9362162534610243e-12
# outer iteration = 904, mass residue = 2.926511916665981e-12
#
# outer iteration = 905, mass residue = 2.931734306880453e-12
# outer iteration = 905, mass residue = 2.9201121685108354e-12
#
# outer iteration = 906, mass residue = 2.9256417217529536e-12
# outer iteration = 906, mass residue = 2.9124028770543855e-12
#
# outer iteration = 907, mass residue = 2.9182661856111844e-12
# outer iteration = 907, mass residue = 2.903181770403836e-12
#
# outer iteration = 908, mass residue = 2.909324718336129e-12
# outer iteration = 908, mass residue = 2.8927590318604402e-12
#
# outer iteration = 909, mass residue = 2.8992212358749166e-12
# outer iteration = 909, mass residue = 2.8811120501189226e-12
#
# outer iteration = 910, mass residue = 2.887852315689812e-12
# outer iteration = 910, mass residue = 2.868232448655741e-12
#
# outer iteration = 911, mass residue = 2.8752392493052468e-12
# outer iteration = 911, mass residue = 2.8541645958154482e-12
#
# outer iteration = 912, mass residue = 2.8614267440412243e-12
# outer iteration = 912, mass residue = 2.8389972067617208e-12
#
# outer iteration = 913, mass residue = 2.8465099310658674e-12
# outer iteration = 913, mass residue = 2.822716715570807e-12
#
# outer iteration = 914, mass residue = 2.8304649868647448e-12
# outer iteration = 914, mass residue = 2.805368229563466e-12
#
# outer iteration = 915, mass residue = 2.8133410740522695e-12
# outer iteration = 915, mass residue = 2.7871352479114258e-12
#
# outer iteration = 916, mass residue = 2.7953438825867046e-12
# outer iteration = 916, mass residue = 2.7679565995289836e-12
#
# outer iteration = 917, mass residue = 2.7763655417765477e-12
# outer iteration = 917, mass residue = 2.7478477613576153e-12
#
# outer iteration = 918, mass residue = 2.756448784919877e-12
# outer iteration = 918, mass residue = 2.726937321329629e-12
#
# outer iteration = 919, mass residue = 2.7357330534571887e-12
# outer iteration = 919, mass residue = 2.705179346235793e-12
#
# outer iteration = 920, mass residue = 2.71414535991818e-12
# outer iteration = 920, mass residue = 2.6825706357257205e-12
#
# outer iteration = 921, mass residue = 2.691694321056706e-12
# outer iteration = 921, mass residue = 2.6591918391273583e-12
#
# outer iteration = 922, mass residue = 2.6684774247931395e-12
# outer iteration = 922, mass residue = 2.635164307048377e-12
#
# outer iteration = 923, mass residue = 2.644614810608426e-12
# outer iteration = 923, mass residue = 2.6104622042179525e-12
#
# outer iteration = 924, mass residue = 2.62005179046632e-12
# outer iteration = 924, mass residue = 2.585093006847105e-12
#
# outer iteration = 925, mass residue = 2.594810244464865e-12
# outer iteration = 925, mass residue = 2.559041366745618e-12
#
# outer iteration = 926, mass residue = 2.568880529411348e-12
# outer iteration = 926, mass residue = 2.532414415906229e-12
#
# outer iteration = 927, mass residue = 2.54237677617376e-12
# outer iteration = 927, mass residue = 2.5052542966273897e-12
#
# outer iteration = 928, mass residue = 2.5153311898956078e-12
# outer iteration = 928, mass residue = 2.477582216519286e-12
#
# outer iteration = 929, mass residue = 2.487766101704699e-12
# outer iteration = 929, mass residue = 2.449501232709772e-12
#
# outer iteration = 930, mass residue = 2.4597866809662345e-12
# outer iteration = 930, mass residue = 2.4208885999162437e-12
#
# outer iteration = 931, mass residue = 2.4312459756455222e-12
# outer iteration = 931, mass residue = 2.391817955085967e-12
#
# outer iteration = 932, mass residue = 2.402255644925e-12
# outer iteration = 932, mass residue = 2.3622549213469103e-12
#
# outer iteration = 933, mass residue = 2.3727636906609925e-12
# outer iteration = 933, mass residue = 2.332461653721587e-12
#
# outer iteration = 934, mass residue = 2.343066265076623e-12
# outer iteration = 934, mass residue = 2.3022159668707367e-12
#
# outer iteration = 935, mass residue = 2.3128586579783694e-12
# outer iteration = 935, mass residue = 2.2716014303391776e-12
#
# outer iteration = 936, mass residue = 2.2823004756734744e-12
# outer iteration = 936, mass residue = 2.240729206882288e-12
#
# outer iteration = 937, mass residue = 2.251490096631267e-12
# outer iteration = 937, mass residue = 2.209542503617643e-12
#
# outer iteration = 938, mass residue = 2.2203447700516712e-12
# outer iteration = 938, mass residue = 2.1782684786043774e-12
#
# outer iteration = 939, mass residue = 2.189128155394355e-12
# outer iteration = 939, mass residue = 2.1467267053366496e-12
#
# outer iteration = 940, mass residue = 2.157601892583248e-12
# outer iteration = 940, mass residue = 2.1149953478994798e-12
#
# outer iteration = 941, mass residue = 2.1258938210917103e-12
# outer iteration = 941, mass residue = 2.0829998273468045e-12
#
# outer iteration = 942, mass residue = 2.093903745723979e-12
# outer iteration = 942, mass residue = 2.0510208362810173e-12
#
# outer iteration = 943, mass residue = 2.0619679133138972e-12
# outer iteration = 943, mass residue = 2.018868669780287e-12
#
# outer iteration = 944, mass residue = 2.0298015695365357e-12
# outer iteration = 944, mass residue = 1.986616500379931e-12
#
# outer iteration = 945, mass residue = 1.9975512191396116e-12
# outer iteration = 945, mass residue = 1.954348305334954e-12
#
# outer iteration = 946, mass residue = 1.9652886030186575e-12
# outer iteration = 946, mass residue = 1.9220223199861845e-12
#
# outer iteration = 947, mass residue = 1.932943919489814e-12
# outer iteration = 947, mass residue = 1.8896058016444836e-12
#
# outer iteration = 948, mass residue = 1.900501742517325e-12
# outer iteration = 948, mass residue = 1.857294198002549e-12
#
# outer iteration = 949, mass residue = 1.8681899226125567e-12
# outer iteration = 949, mass residue = 1.824989485394175e-12
#
# outer iteration = 950, mass residue = 1.8358508444596636e-12
# outer iteration = 950, mass residue = 1.7927082100480142e-12
#
# outer iteration = 951, mass residue = 1.803531693952411e-12
# outer iteration = 951, mass residue = 1.7603890238746286e-12
#
# outer iteration = 952, mass residue = 1.771166917564017e-12
# outer iteration = 952, mass residue = 1.7281731148258946e-12
#
# outer iteration = 953, mass residue = 1.738923937838303e-12
# outer iteration = 953, mass residue = 1.6962252084540486e-12
# outer iteration = 954, mass residue = 1.7069573514737478e-12
# outer iteration = 954, mass residue = 1.664410060097259e-12
#
# outer iteration = 955, mass residue = 1.6750736192251356e-12
# outer iteration = 955, mass residue = 1.6326362143124634e-12
#
# outer iteration = 956, mass residue = 1.6432256316848861e-12
# outer iteration = 956, mass residue = 1.6009538771260702e-12
#
# outer iteration = 957, mass residue = 1.6114813589226932e-12
# outer iteration = 957, mass residue = 1.5695191406165416e-12
#
# outer iteration = 958, mass residue = 1.579998460180139e-12
# outer iteration = 958, mass residue = 1.5381990557442902e-12
#
# outer iteration = 959, mass residue = 1.5486044740250556e-12
# outer iteration = 959, mass residue = 1.5072326510098483e-12
#
# outer iteration = 960, mass residue = 1.5175863929891355e-12
# outer iteration = 960, mass residue = 1.4762700610584996e-12
#
# outer iteration = 961, mass residue = 1.4865128589011429e-12
# outer iteration = 961, mass residue = 1.4455354589986601e-12
#
# outer iteration = 962, mass residue = 1.4557172330406247e-12
# outer iteration = 962, mass residue = 1.4151916158579551e-12
#
# outer iteration = 963, mass residue = 1.4253157540173553e-12
# outer iteration = 963, mass residue = 1.3849750141574762e-12
#
# outer iteration = 964, mass residue = 1.3949893545329798e-12
# outer iteration = 964, mass residue = 1.35512743685276e-12
#
# outer iteration = 965, mass residue = 1.3650751771939228e-12
# outer iteration = 965, mass residue = 1.3255368825420772e-12
#
# outer iteration = 966, mass residue = 1.335382583578804e-12
# outer iteration = 966, mass residue = 1.2962076424631819e-12
#
# outer iteration = 967, mass residue = 1.3059552277736076e-12
# outer iteration = 967, mass residue = 1.2672161819198197e-12
#
# outer iteration = 968, mass residue = 1.2768735355922687e-12
# outer iteration = 968, mass residue = 1.2383635361503363e-12
#
# outer iteration = 969, mass residue = 1.2478973363656367e-12
# outer iteration = 969, mass residue = 1.2098765772206188e-12
#
# outer iteration = 970, mass residue = 1.2193330170019722e-12
# outer iteration = 970, mass residue = 1.181783658259492e-12
#
# outer iteration = 971, mass residue = 1.1911467567993975e-12
# outer iteration = 971, mass residue = 1.153912187029059e-12
#
# outer iteration = 972, mass residue = 1.1631504620037874e-12
# outer iteration = 972, mass residue = 1.126317179833534e-12
#
# outer iteration = 973, mass residue = 1.1354511351310226e-12
# outer iteration = 973, mass residue = 1.0992319427719953e-12
#
# outer iteration = 974, mass residue = 1.1082859799313152e-12
# outer iteration = 974, mass residue = 1.072364556397184e-12
#
# outer iteration = 975, mass residue = 1.0812834565530595e-12
# outer iteration = 975, mass residue = 1.0460162776358343e-12
#
# outer iteration = 976, mass residue = 1.0548461318354709e-12
# outer iteration = 976, mass residue = 1.01991055278413e-12
#
# outer iteration = 977, mass residue = 1.0286035914953903e-12
# outer iteration = 977, mass residue = 9.94183529576464e-13
#
# outer iteration = 978, mass residue = 1.0027663464347163e-12
# outer iteration = 978, mass residue = 9.688408829930726e-13
#
# outer iteration = 979, mass residue = 9.773078802692225e-13
# outer iteration = 979, mass residue = 9.439384286375724e-13
#
# outer iteration = 980, mass residue = 9.522958804243915e-13
# outer iteration = 980, mass residue = 9.194747462998947e-13
#
# outer iteration = 981, mass residue = 9.277089086257175e-13
# outer iteration = 981, mass residue = 8.9536254917875e-13
#
# outer iteration = 982, mass residue = 9.034637481346966e-13
# outer iteration = 982, mass residue = 8.715297068782707e-13
#
# outer iteration = 983, mass residue = 8.794943352339032e-13
# outer iteration = 983, mass residue = 8.48166416111296e-13
#
# outer iteration = 984, mass residue = 8.560252283132093e-13
# outer iteration = 984, mass residue = 8.252420622400152e-13
#
# outer iteration = 985, mass residue = 8.32979451230798e-13
# outer iteration = 985, mass residue = 8.025599277755904e-13
#
# outer iteration = 986, mass residue = 8.101507938756957e-13
# outer iteration = 986, mass residue = 7.802664207295704e-13
#
# outer iteration = 987, mass residue = 7.877439698494145e-13
# outer iteration = 987, mass residue = 7.582662252100972e-13
#
# outer iteration = 988, mass residue = 7.656121558643307e-13
# outer iteration = 988, mass residue = 7.367316812973612e-13
#
# outer iteration = 989, mass residue = 7.439788596033584e-13
# outer iteration = 989, mass residue = 7.15605882082885e-13
#
# outer iteration = 990, mass residue = 7.227284022415925e-13
# outer iteration = 990, mass residue = 6.947524067947966e-13
#
# outer iteration = 991, mass residue = 7.017411572029154e-13
# outer iteration = 991, mass residue = 6.742989943179215e-13
#
# outer iteration = 992, mass residue = 6.811813552320659e-13
# outer iteration = 992, mass residue = 6.542392766677031e-13
#
# outer iteration = 993, mass residue = 6.610052218874724e-13
# outer iteration = 993, mass residue = 6.345569933063907e-13
#
# outer iteration = 994, mass residue = 6.412000859209843e-13
# outer iteration = 994, mass residue = 6.150797051450125e-13
#
# outer iteration = 995, mass residue = 6.21590000453305e-13
# outer iteration = 995, mass residue = 5.958624399222357e-13
#
# outer iteration = 996, mass residue = 6.022621180111875e-13
# outer iteration = 996, mass residue = 5.771719476042977e-13
#
# outer iteration = 997, mass residue = 5.834936589310505e-13
# outer iteration = 997, mass residue = 5.586875205517535e-13
#
# outer iteration = 998, mass residue = 5.648735607335046e-13
# outer iteration = 998, mass residue = 5.405553397985831e-13
#
# outer iteration = 999, mass residue = 5.466458013529014e-13
# outer iteration = 999, mass residue = 5.228358758605683e-13
#
# outer iteration = 1000, mass residue = 5.288282086853386e-13
# outer iteration = 1000, mass residue = 5.053941958114924e-13

# %% [markdown]
# # Post-processing
#
# Interpolate velocities to scalar cell corners

# %%
for j in range(2,ny+1):
    for i in range(2,nx+1):
        u_nodal[j,i] = 0.5*(u[j,i]+u[j-1,i])
        v_nodal[j,i] = 0.5*(v[j,i]+v[j,i-1])
        p_nodal[j,i] = 0.25*(p[j,i]+p[j-1,i]+p[j-1,i-1]+p[j,i-1])

# east and west boundaries
u_nodal[2:ny+1,1] = 0.5*(u[2:ny+1,1]+u[1:ny,1]) # normal velocity u on west boundary has index 1
u_nodal[2:ny+1,nx+1] = 0.5*(u[2:ny+1,nx+1]+u[1:ny,nx+1])
v_nodal[2:ny+1,1] = v[2:ny+1,0]  # tangential velocity v on left boundary has index 0
v_nodal[2:ny+1,nx+1] = v[2:ny+1,nx+1]
p_nodal[2:ny+1,1] = 0.5*(p[2:ny+1,1]+p[1:ny,1]) # pressure at the west boundary (zero-gradient b.c., p(x=0)=p(dx/2))
p_nodal[2:ny+1,nx+1] = 0.5*(p[2:ny+1,nx]+p[1:ny,nx]) # pressure at the east boundary (zero-gradient b.c., p(x=1)=p(1-dx/2))

# north and south boundaries
u_nodal[1,2:nx+1] = u[0,2:nx+1] # tangential velocity u on south boundary has index 0
u_nodal[ny+1,2:nx+1] = u[ny+1,2:nx+1]
v_nodal[1,2:nx+1] = 0.5*(v[1,2:nx+1]+v[1,1:nx])  # normal velocity v on south boundary has index 1
v_nodal[ny+1,2:nx+1] = 0.5*(v[ny+1,2:nx+1]+v[ny+1,1:nx])
p_nodal[1,2:nx+1] = 0.5*(p[1,2:nx+1]+p[1,1:nx]) # pressure at the south boundary (zero-gradient b.c., p(y=0)=p(dy/2))
p_nodal[ny+1,2:nx+1] = 0.5*(p[ny,2:nx+1]+p[ny,1:nx]) # pressure at the north boundary (zero-gradient b.c., p(y=1)=p(1-dy/2))

# southwest corner
u_nodal[1,1] = 0.0
v_nodal[1,1] = 0.0
p_nodal[1,1] = p_nodal[2,2] # neumann b.c. and reference pressure
#p_nodal[1,1] = p[1,1]

# southeast corner
u_nodal[1,nx+1] = 0.0
v_nodal[1,nx+1] = 0.0
p_nodal[1,nx+1] = p[1,nx] # neumann b.c. on south and east boundaries

# northeast corner
u_nodal[ny+1,nx+1] = 0.0
v_nodal[ny+1,nx+1] = 0.0
p_nodal[ny+1,nx+1] = p[ny,nx] # neumann b.c. on north and east boundaries

# northwest corner
u_nodal[ny+1,1] = 0.0
v_nodal[ny+1,1] = 0.0
p_nodal[ny+1,1] = p[ny,1] # neumann b.c. on north and west boundaries

# For blocked out regions only
#u_nodal[1:13,20:21] = 0.0
#v_nodal[1:13,20:21] = 0.0

# %%
x = np.zeros([ny+2,nx+2]) 
y = np.zeros([ny+2,nx+2])

# %%
for j in range(1,ny+2):
    for i in range(1,nx+2):
        x[j,i] = (i-1)*dx
        y[j,i] = (j-1)*dy
        Vel_mag[j,i] = np.sqrt(u_nodal[j,i]**2.+v_nodal[j,i]**2.)

# %%
fig = plt.figure(figsize=(12,3),dpi=600)
CS = plt.contourf(x[1:ny+2,1:nx+2],y[1:ny+2,1:nx+2],Vel_mag[1:ny+2,1:nx+2],levels=101,cmap='jet')
plt.colorbar(CS);
#plt.clabel(CS,fontsize=10,inline=1,fmt='%3.2f');
plt.savefig('Vel_mag_cont.png');

# %%
fig = plt.figure(figsize=[12,3],dpi=600)
#ax = plt.subplot(1,2,1)
pcont = plt.contourf(x[1:ny+2,1:nx+2],y[1:ny+2,1:nx+2],p_nodal[1:ny+2,1:nx+2],levels=51, cmap=plt.cm.Spectral)
plt.colorbar(pcont)

plt.quiver(x[1:ny+2:2,1:nx+2:2],y[1:ny+2:2,1:nx+2:2],u_nodal[1:ny+2:2,1:nx+2:2],v_nodal[1:ny+2:2,1:nx+2:2],color='black')
#plt.streamplot(x[1:ny+2,1:nx+2],y[1:ny+2,1:nx+2],u_nodal[1:ny+2,1:nx+2],v_nodal[1:ny+2,1:nx+2],color='blue')
plt.xlim([0,10])
plt.ylim([0,1])
plt.title('Pressure contour and Velocity Vectors')
#plt.axis('equal')
plt.savefig('Quiver_Plot.png')

# %%
fig = plt.figure(dpi=600)
plt.plot(u_nodal[:,1],y[:,1],'b-',lw=2)
plt.plot(u_nodal[:,int(nx/2)],y[:,int(nx/2)],'r-.o',lw=2)
plt.plot(u_nodal[:,-1],y[:,-1],'g-.*',lw=2)
#plt.plot(x[int(ny/2),:],v_nodal[int(ny/2),:])
plt.legend(['$x=0$','$x=L/2$','$x=L$'])
#plt.axis('equal')
plt.title('u-velocity profile for a fully developed channel flow')
plt.savefig('Fully_Developed_Vel_Profile.png')

# %% [markdown]
# # Try it yourself
#
# What effect does increasing the Reynolds number have on the centerline velocity for the channel flow problem?
#
# Increasing the Reynolds number decreases the centerline velocity at the exit as the flow is not fully developed at significantly higher Reynolds numbers.
